# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression, Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.datasets import load_files
df = pd.read_csv('PCA.csv')

# %%
df.shape
# Out:
# (2000, 15)

# %%
X = df.select_dtypes(include=['number'])

pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X)

print(X_reduced.shape)

plt.scatter(X_reduced[:, 0], X_reduced[:, 1], alpha=0.5,)
plt.title("2D PCA")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
# Out:
# (2000, 2)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(X, test_size=0.3, random_state=20)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)

plt.scatter(X_train_reduced[:, 0], X_train_reduced[:, 1], alpha=0.3, label="Train")
plt.scatter(X_test_reduced[:, 0], X_test_reduced[:, 1], alpha=0.3, label="Test")
plt.title("2D PCA (Train/Test)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend()
plt.show()
# Out:
# Train shape: (1400, 15)
# Test shape: (600, 15)

# %%
start_time = time.time()

pca = PCA(n_components=2)
X_train_reduced = pca.fit_transform(X_train)

end_time = time.time()

train_time_ms = (end_time - start_time) * 1000
print(f"Training time: {train_time_ms:.2f} ms")

X_test_reduced = pca.transform(X_test)
# Out:
# Training time: 3.10 ms
